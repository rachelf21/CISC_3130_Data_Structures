# %%
# Rachel Friedman | Data Structures 3130 | Assignment 1 | February 2, 2020
from beautifultable import BeautifulTable
import pandas as pd

def dollar(x):
    return "${:.2f}".format(x)

def single(x):
    return "{:.0f}".format(x)  

file = open("testfile.txt","w") 
master = pd.read_excel("assignment1.xlsx","master")
trans = pd.read_excel("assignment1.xlsx","transactions")
trans["Total"] = trans["Price"]*trans["Quantity"]
trans.fillna(0, inplace=True) #replace missing values
total_order_amount = pd.DataFrame(trans[trans['Type']=='O'].groupby(["Cust_Number"])["Total"].sum()) #creates table of total order amt per customer
total_payment_amount = pd.DataFrame(trans[trans['Type']=='P'].groupby("Cust_Number")["Payment"].sum()) #creates table of total payment amt per customer

# %%
for i in range(len(master['Cust_Number'])):  #cycles through list of customers
    x = master['Cust_Number'].iloc[i]  #sets current customer number
    cust_name = master[master['Cust_Number']== x]['Name'].tolist()[0]
    cust_trans = trans[(trans['Cust_Number']== x)][["Trans_Number","Item","Price","Quantity"]] #generates all transactions for current customer
    cust_trans['Price'] = cust_trans['Price'].apply(dollar) #format as currency
    cust_trans['Quantity'] = cust_trans['Quantity'].apply(single) #format with no decimals
    prev_bal =  master[master['Cust_Number']==x]['Balance'].tolist()[0]
    total_order = total_order_amount.loc[x].tolist()[0]
    total_payment = total_payment_amount.loc[x].tolist()[0]
    balance = prev_bal + total_order - total_payment
    
    print("\n\n--------------------------------------------------------")
    print("  ***** CUSTOMER INVOICE ***** CUSTOMER INVOICE ***** " )
    print("--------------------------------------------------------")
    print("\nCUSTOMER NAME:", cust_name, "\t CUSTOMER NUMBER:", x)
    print("PREVIOUS BALANCE:", "${:,.2f}".format(prev_bal),"\n")
    table=BeautifulTable()
    table.column_headers=["Transaction#","Item Ordered/\nPayment","Order Amount/\nPayment Amount","Quantity"]
    for i in range(len(cust_trans)):
        table.append_row(cust_trans.iloc[i])
    table.set_style(BeautifulTable.STYLE_BOX_ROUNDED)#  STYLE_BOX_ROUNDED  STYLE_SEPARATED
    print(table)    
    print("\n\t\t\t\tBALANCE DUE: ${:,.2f}".format(balance))
    print("\nPlease remit payment at your earliest convenience. \nThank you.")

    file.write("\n\n--------------------------------------------------------")
    file.write("  ***** CUSTOMER INVOICE ***** CUSTOMER INVOICE ***** " )
    file.write("--------------------------------------------------------")
    file.write("\nCUSTOMER NAME:"+ cust_name+"\t CUSTOMER NUMBER:"+ str(x))
    file.write("PREVIOUS BALANCE:"+ "${:,.2f}".format(prev_bal)+"\n")
    table=BeautifulTable()
    table.column_headers=["Transaction#","Item Ordered/\nPayment","Order Amount/\nPayment Amount","Quantity"]
    for i in range(len(cust_trans)):
        table.append_row(cust_trans.iloc[i])
        file.write(str(cust_trans.iloc[i]))
    table.set_style(BeautifulTable.STYLE_BOX_ROUNDED)#  STYLE_BOX_ROUNDED  STYLE_SEPARATED
    #file.write(str(table))   
    file.write("\n\t\t\t\tBALANCE DUE: ${:,.2f}".format(balance))
    file.write("\nPlease remit payment at your earliest convenience. \nThank you.")
    
file.close()
# Out:
# --------------------------------------------------------
#   ***** CUSTOMER INVOICE ***** CUSTOMER INVOICE *****
# --------------------------------------------------------
#
# CUSTOMER NAME: ABC Computing 	 CUSTOMER NUMBER: 1236
# PREVIOUS BALANCE: $345.89
#
# ╭──────────────┬───────────────────────────────────┬────────────────┬──────────╮
# │ Transaction# │           Item Ordered/           │ Order Amount/  │ Quantity │
# │              │              Payment              │ Payment Amount │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9891     │              Payment              │   $-1000.00    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9743     │              Payment              │    $-422.00    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9244     │    Dell Inspiron 3583 Notebook    │    $539.99     │    5     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9638     │ Dell UltraSharp U2419H Full HD 19 │    $189.99     │    3     │
# │              │             20 x 1080             │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9822     │ SAMSUNG 398 Series C27F398 27" Fu │    $179.99     │    4     │
# │              │         ll HD 1920 x 1080         │                │          │
# ╰──────────────┴───────────────────────────────────┴────────────────┴──────────╯
#
# 				BALANCE DUE: $2,913.77
#
# Please remit payment at your earliest convenience.
# Thank you.
#
#
# --------------------------------------------------------
#   ***** CUSTOMER INVOICE ***** CUSTOMER INVOICE *****
# --------------------------------------------------------
#
# CUSTOMER NAME: Games and Gadgets 	 CUSTOMER NUMBER: 1301
# PREVIOUS BALANCE: $13,670.15
#
# ╭──────────────┬───────────────────────────────────┬────────────────┬──────────╮
# │ Transaction# │           Item Ordered/           │ Order Amount/  │ Quantity │
# │              │              Payment              │ Payment Amount │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9622     │              Payment              │   $-1200.00    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9477     │ ASUS VivoBook 15 Thin and Light L │    $659.99     │    3     │
# │              │               aptop               │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9688     │              Payment              │    $-300.00    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9360     │  Lenovo 100e Chromebook 2nd Gen   │    $119.99     │    9     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9930     │ Intel Core i9-9820X Skylake X 10- │    $599.99     │    8     │
# │              │           Core 3.3 GHz            │                │          │
# ╰──────────────┴───────────────────────────────────┴────────────────┴──────────╯
#
# 				BALANCE DUE: $20,029.95
#
# Please remit payment at your earliest convenience.
# Thank you.
#
#
# --------------------------------------------------------
#   ***** CUSTOMER INVOICE ***** CUSTOMER INVOICE *****
# --------------------------------------------------------
#
# CUSTOMER NAME: Max's Mobile 	 CUSTOMER NUMBER: 1349
# PREVIOUS BALANCE: $805.65
#
# ╭──────────────┬───────────────────────────────────┬────────────────┬──────────╮
# │ Transaction# │           Item Ordered/           │ Order Amount/  │ Quantity │
# │              │              Payment              │ Payment Amount │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9502     │              Payment              │    $-875.70    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9317     │ ASUS AMD AM4 ROG Strix X570-E Gam │    $299.99     │    1     │
# │              │        ing ATX Motherboard        │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9451     │ SanDisk 128GB Ultra Flair CZ73 US │     $17.65     │    24    │
# │              │         B 3.0 Flash Drive         │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9750     │ GeForce RTX 2070 SUPER XC ULTRA G │    $549.99     │    5     │
# │              │               AMING               │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9977     │ Seasonic PRIME Ultra 550W 80+ Pla │    $121.99     │    3     │
# │              │        tinum Power Supply         │                │          │
# ╰──────────────┴───────────────────────────────────┴────────────────┴──────────╯
#
# 				BALANCE DUE: $3,769.46
#
# Please remit payment at your earliest convenience.
# Thank you.
#
#
# --------------------------------------------------------
#   ***** CUSTOMER INVOICE ***** CUSTOMER INVOICE *****
# --------------------------------------------------------
#
# CUSTOMER NAME: Techaholic 	 CUSTOMER NUMBER: 1380
# PREVIOUS BALANCE: $1,500.32
#
# ╭──────────────┬───────────────────────────────────┬────────────────┬──────────╮
# │ Transaction# │           Item Ordered/           │ Order Amount/  │ Quantity │
# │              │              Payment              │ Payment Amount │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9010     │              Payment              │    $-750.45    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9317     │ Creative Sound Blaster Zx 116dB P │    $149.99     │    9     │
# │              │       CIe Gaming Sound Card       │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9970     │ ASUS - Gaming Desktop PC - Intel  │    $815.99     │    4     │
# │              │           Core i5-9400F           │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9989     │  DELL Laptop XPS XPS9370-7040SLV  │    $1889.99    │    1     │
# ╰──────────────┴───────────────────────────────────┴────────────────┴──────────╯
#
# 				BALANCE DUE: $7,253.73
#
# Please remit payment at your earliest convenience.
# Thank you.
#
#
# --------------------------------------------------------
#   ***** CUSTOMER INVOICE ***** CUSTOMER INVOICE *****
# --------------------------------------------------------
#
# CUSTOMER NAME: Wired 	 CUSTOMER NUMBER: 1522
# PREVIOUS BALANCE: $1,298.75
#
# ╭──────────────┬───────────────────────────────────┬────────────────┬──────────╮
# │ Transaction# │           Item Ordered/           │ Order Amount/  │ Quantity │
# │              │              Payment              │ Payment Amount │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9487     │ Intel Core i9-9900K 8-Core proces │    $524.99     │    4     │
# │              │                sor                │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9884     │              Payment              │    $-500.00    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9109     │    Dell Inspiron 3583 Notebook    │    $539.99     │    2     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9577     │ Dell UltraSharp U2419H Full HD 19 │    $189.99     │    5     │
# │              │             20 x 1080             │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9296     │ SAMSUNG 398 Series C27F398 27" Fu │    $179.99     │    2     │
# │              │         ll HD 1920 x 1080         │                │          │
# ╰──────────────┴───────────────────────────────────┴────────────────┴──────────╯
#
# 				BALANCE DUE: $5,288.62
#
# Please remit payment at your earliest convenience.
# Thank you.
#
#
# --------------------------------------------------------
#   ***** CUSTOMER INVOICE ***** CUSTOMER INVOICE *****
# --------------------------------------------------------
#
# CUSTOMER NAME: Tech Inc 	 CUSTOMER NUMBER: 1546
# PREVIOUS BALANCE: $1,898.99
#
# ╭──────────────┬───────────────────────────────────┬────────────────┬──────────╮
# │ Transaction# │           Item Ordered/           │ Order Amount/  │ Quantity │
# │              │              Payment              │ Payment Amount │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9628     │              Payment              │    $-100.00    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9715     │ ASUS VivoBook 15 Thin and Light L │    $659.99     │    6     │
# │              │               aptop               │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9769     │              Payment              │    $-250.00    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9580     │  Lenovo 100e Chromebook 2nd Gen   │    $119.99     │    1     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9438     │ Intel Core i9-9820X Skylake X 10- │    $599.99     │    8     │
# │              │           Core 3.3 GHz            │                │          │
# ╰──────────────┴───────────────────────────────────┴────────────────┴──────────╯
#
# 				BALANCE DUE: $10,428.84
#
# Please remit payment at your earliest convenience.
# Thank you.
#
#
# --------------------------------------------------------
#   ***** CUSTOMER INVOICE ***** CUSTOMER INVOICE *****
# --------------------------------------------------------
#
# CUSTOMER NAME: Fast Fix 	 CUSTOMER NUMBER: 1626
# PREVIOUS BALANCE: $0.00
#
# ╭──────────────┬───────────────────────────────────┬────────────────┬──────────╮
# │ Transaction# │           Item Ordered/           │ Order Amount/  │ Quantity │
# │              │              Payment              │ Payment Amount │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9611     │ Creative Sound Blaster Zx 116dB P │    $149.99     │    5     │
# │              │       CIe Gaming Sound Card       │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9660     │ Seasonic PRIME Ultra 550W 80+ Pla │    $121.99     │    6     │
# │              │        tinum Power Supply         │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9546     │              Payment              │    $-500.00    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9557     │ Creative Sound Blaster Zx 116dB P │    $149.99     │    9     │
# │              │       CIe Gaming Sound Card       │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9876     │ ASUS - Gaming Desktop PC - Intel  │    $815.99     │    2     │
# │              │           Core i5-9400F           │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9653     │  DELL Laptop XPS XPS9370-7040SLV  │    $1889.99    │    2     │
# ╰──────────────┴───────────────────────────────────┴────────────────┴──────────╯
#
# 				BALANCE DUE: $7,743.76
#
# Please remit payment at your earliest convenience.
# Thank you.
#
#
# --------------------------------------------------------
#   ***** CUSTOMER INVOICE ***** CUSTOMER INVOICE *****
# --------------------------------------------------------
#
# CUSTOMER NAME: Dollar Devices 	 CUSTOMER NUMBER: 1711
# PREVIOUS BALANCE: $1,494.10
#
# ╭──────────────┬───────────────────────────────────┬────────────────┬──────────╮
# │ Transaction# │           Item Ordered/           │ Order Amount/  │ Quantity │
# │              │              Payment              │ Payment Amount │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9875     │              Payment              │    $-870.00    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9405     │  Lenovo 100e Chromebook 2nd Gen   │    $119.99     │    10    │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9142     │ Intel Core i9-9820X Skylake X 10- │    $599.99     │    5     │
# │              │           Core 3.3 GHz            │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9241     │ Intel Z390 SATA 6Gb USB 3.1 ATX I │    $125.99     │    1     │
# │              │         ntel Motherboard          │                │          │
# ╰──────────────┴───────────────────────────────────┴────────────────┴──────────╯
#
# 				BALANCE DUE: $4,949.94
#
# Please remit payment at your earliest convenience.
# Thank you.
#
#
# --------------------------------------------------------
#   ***** CUSTOMER INVOICE ***** CUSTOMER INVOICE *****
# --------------------------------------------------------
#
# CUSTOMER NAME: Best Buy 	 CUSTOMER NUMBER: 1808
# PREVIOUS BALANCE: $650.00
#
# ╭──────────────┬───────────────────────────────────┬────────────────┬──────────╮
# │ Transaction# │           Item Ordered/           │ Order Amount/  │ Quantity │
# │              │              Payment              │ Payment Amount │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9711     │              Payment              │   $-3000.00    │    0     │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9045     │ ASUS AMD AM4 ROG Strix X570-E Gam │    $299.99     │    3     │
# │              │        ing ATX Motherboard        │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9636     │ SanDisk 128GB Ultra Flair CZ73 US │     $17.65     │    50    │
# │              │         B 3.0 Flash Drive         │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9432     │ GeForce RTX 2070 SUPER XC ULTRA G │    $549.99     │    7     │
# │              │               AMING               │                │          │
# ├──────────────┼───────────────────────────────────┼────────────────┼──────────┤
# │     9319     │ Seasonic PRIME Ultra 550W 80+ Pla │    $121.99     │    4     │
# │              │        tinum Power Supply         │                │          │
# ╰──────────────┴───────────────────────────────────┴────────────────┴──────────╯
#
# 				BALANCE DUE: $3,770.36
#
# Please remit payment at your earliest convenience.
# Thank you.
